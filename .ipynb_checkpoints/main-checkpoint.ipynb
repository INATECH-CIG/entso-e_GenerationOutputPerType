# %% [markdown]
# # entso e Actual Generation per Type data

# %% [markdown]
# In this Jupyter Notebook we importing the entso e Actual Generation per Type data and ...
#
# aggregating the data from hourly up to quarterly hourly data to monthly values.

# %% [markdown]
# ## Data sources

# %% [markdown]
# 1. ENTSO-E Transparency Platform, Actual Generation per Type Available online: https://transparency.entsoe.eu/generation/r2/actualGenerationPerProductionType/show (accessed on Oct 02, 2020).
#
# Hint: Using the sftp server is recommended to download the needed data files (https://entsoe.zendesk.com/hc/en-us/articles/115000173266-Overview-of-data-download-options-on-Transparency-Platform)

# %% [markdown]
# ## Import python libraries

# %%
import numpy as np
import pandas as pd

#Helpers
import os
import pycountry
import glob

#Ploting
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [15, 6]

# %% [markdown]
# ## Set data directories

# %% [markdown]
# Create input, processed and output folders if they don't exist. If the paths are relative, the correspoding folders will be created inside the current working directory.

# %%
input_directory_path = os.path.join('input')
processed_directory_path = 'processed'
output_directory_path = os.path.join('output')

os.makedirs(input_directory_path, exist_ok=True)
os.makedirs(processed_directory_path, exist_ok=True)
os.makedirs(output_directory_path, exist_ok=True)

# %% [markdown]
# ## Define functions¶

# %%
# Import function

def import_entsoe_Generation_per_Type(path):
    """
    Load and standardize the raw entsoe_Generation_per_Type files.

    Parameters
    ----------
    path : Path to data directory


    """
    
    
    # combining path and .csv data
    
    filenames = sorted(glob.glob(path + "/*.csv"))
    
    # import csv files
    # using pd.concat function as import function to append data to dataframe
    # encoding: "utf-16" see entso-e documentation
    # colum selection is possible by using "usecols=['DateTime','ResolutionCode','AreaCode','AreaTypeCode','GenerationUnitEIC',...]" 
    
    entsoe_timeseries = pd.concat((pd.read_csv(f, sep='\t', encoding='utf-16', index_col = 3) for f in filenames))
    
    #entsoe_timeseries.drop(columns=["Year","Month","Day"], inplace=True)
    
    #entsoe_timeseries.index = pd.to_datetime(entsoe_pp_timeseries.index)

    #set generation and consumtion as absolut value (assuming that the negative entries are incorrect)
    #entsoe_pp_timeseries['ActualGenerationOutput'] = entsoe_pp_timeseries.ActualGenerationOutput.abs()
    
    #entsoe_pp_timeseries['ActualConsumption'] = entsoe_pp_timeseries.ActualConsumption.abs()

    return entsoe_timeseries

# %%
# resampling function for production time series

def resampling (pp_gen, start='2018-01-01', end='2019-01-01', resolution='60Min'):       
    
    """
    Provides resampling for entso e Actual Generation per Generation Unit data.
    
    Parameters
    ----------
    pp_gen : pd.DataFrame
        entso e Actual Generation per Generation Unit data for one GenerationUnitEIC
        Columns: ['ActualGenerationOutput', 'ActualConsumption', 'ResolutionCode', 'GenerationUnitEIC']
    
    GenerationUnitEIC: string
        Generation unit identifier EIC.
        
    start : string
        start date
    
    end : string
        end date
        
    resolution : string
        
    Returns
    -------
    pp_gen : pd.DataFrame
        Production time-series for power plant with unit identifier EIC.
        
    """
    
    if pp_gen.ResolutionCode.iloc[0] == 'PT60M':
        t_index = pd.date_range(start=start, end=end, freq='60Min', closed='left')
    
        pp_gen = pp_gen.reindex(t_index).copy()
    
        pp_gen.fillna(value=0, inplace = True)
        
        pp_gen = pp_gen.resample(rule='60Min').apply({'ActualGenerationOutput': 'mean','ActualConsumption': 'mean'})


    elif pp_gen.ResolutionCode.iloc[0] == 'PT30M':
        t_index = pd.date_range(start=start, end=end, freq='30Min', closed='left')
    
        pp_gen = pp_gen.reindex(t_index).copy()     
    
        pp_gen.fillna(0, inplace = True)
        
        pp_gen = pp_gen.resample(rule='60Min').apply({'ActualGenerationOutput': 'mean','ActualConsumption': 'mean'})
        
    elif pp_gen.ResolutionCode.iloc[0] == 'PT15M':
        t_index = pd.date_range(start=start, end=end, freq='15Min', closed='left')
    
        pp_gen = pp_gen.reindex(t_index).copy()
    
        pp_gen.fillna(0, inplace = True)
        
        pp_gen = pp_gen.resample(rule='60Min').apply({'ActualGenerationOutput': 'mean','ActualConsumption': 'mean'})
    
    return pp_gen

# %%
def change_ProductionTypeName (entsoe_timeseries):
    return entsoe_timeseries.ProductionTypeName.replace(
                                {'Fossil Hard coal': 'Hard Coal',
                                 'Fossil Brown coal/Lignite':'Lignite',
                                 'Fossil Gas': 'Gas',
                                 'Fossil Oil' : 'Other fossil',
                                 'Fossil Coal-derived gas': 'Other fossil',
                                 'Fossil Peat': 'Other fossil',
                                 'Fossil Oil Shale' : 'Other fossil',
                                 'Other' : 'Other fossil',
                                 '.*Hydro.*': 'Hydro',
                                 '.*Oil.*': 'Oil'
                                 }, regex = True, inplace = True)

# %% [markdown]
# ## Set filter parameter

# %%
# Change the production type names
new_ProductionTypeName = False

#old                        : new
#------------------------------------------------
#'Fossil Hard coal'         : 'Hard Coal',
#'Fossil Brown coal/Lignite': 'Lignite',
#'Fossil Gas'               : 'Gas',
#'Fossil Oil'               : 'Other fossil',
#'Fossil Coal-derived gas'  : 'Other fossil',
#'Fossil Peat'              : 'Other fossil',
#'Fossil Oil Shale'         : 'Other fossil',
#'Other'                    : 'Other fossil',
#'.*Hydro.*'                : 'Hydro',
#'.*Oil.*'                  : 'Oil'

# dataset period
start = '2019-01-01'
end = '2020-01-01'
closed='left' # end is not included 

# test dataet about gaps, timedate and duplicates
test_dataset = False

# countries to analyze
#countries = ['AT', 'BE', 'BG', 'CH', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'ME', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK']

#'AL', 
#missing in the data 'BA', 'MK'

#Dic to convert between alpha 3 and alpha 2
countries_dic = {}
for country in pycountry.countries:
    countries_dic[country.alpha_3] = country.alpha_2

# %% [markdown]
# ## Load and filter data¶

# %%
# load and standardize data

entsoe_gen_type = import_entsoe_Generation_per_Type(input_directory_path)

# %%
# check the availbe columns

entsoe_gen_type.columns
# Out:
# Index(['Year', 'Month', 'Day', 'ResolutionCode', 'areacode', 'AreaTypeCode',
#        'AreaName', 'MapCode', 'ProductionType', 'ActualGenerationOutput',
#        'ActualConsumption', 'UpdateTime'],
#       dtype='object')

# %%
# check the availbe 'ProductionTypeName'

entsoe_gen_unit.ProductionTypeName.unique()
# Out:
# array(['Fossil Hard coal', 'Hydro Pumped Storage', 'Fossil Gas',
#        'Nuclear', 'Fossil Brown coal/Lignite', 'Fossil Oil',
#        'Hydro Water Reservoir', 'Hydro Run-of-river and poundage',
#        'Waste', 'Fossil Coal-derived gas', 'Other', 'Biomass', 'Solar',
#        'Wind Offshore', 'Geothermal', 'Fossil Oil shale', 'Wind Onshore',
#        'Fossil Peat'], dtype=object)

# %%
# check the availbe countries

entsoe_gen_unit.MapCode.unique()
# Out:
# array(['DE_Amprion', 'DE_TenneT_GER', 'DE_TransnetBW', 'DE_50HzT', 'CH',
#        'AT', 'HU', 'PT', 'FR', 'ES', 'PL', 'ME', 'BE', 'SK', 'IT', 'CZ',
#        'SI', 'GR', 'RO', 'BG', 'BA', 'EE', 'LT', 'LV', 'FI', 'DK', 'SE',
#        'IE', 'NIE', 'NL', 'GB'], dtype=object)

# %%
# replace DE_* names with DE (DE is represend as four areas)

entsoe_gen_unit.MapCode.replace({'.*DE.*' : 'DE'}, regex = True, inplace = True)

# %%
# new names for production types

if new_ProductionTypeName:
    entsoe_gen_unit = change_ProductionTypeName(entsoe_gen_unit)

# %%
# Which resolutions do exist in the data?

entsoe_gen_unit.ResolutionCode.unique()
# Out:
# array(['PT60M', 'PT15M', 'PT30M'], dtype=object)

# %%
# How many generators in the data

len(entsoe_gen_unit.GenerationUnitEIC.unique().tolist())
# Out:
# 1788

# %%
if test_dataset:
    for i in entsoe_gen_unit.GenerationUnitEIC.unique():
        unit_gen = entsoe_gen_unit.query("GenerationUnitEIC == @i")

        # test if different resolution codes exist for one power plant
        if len(unit_gen.ResolutionCode.unique()) >= 2:
            print('The data for generator ' + unit_gen.GenerationUnitEIC.iloc[0] + ' contains different time resolutions')
            # for 2018 all data OK
            # for 2019 all data OK
        
        if unit_gen.index.has_duplicates:
            #print('The data for generator ' + unit_gen.GenerationUnitEIC.iloc[0] + ' contains duplicates in the index')
            #many duplicates in 2019!
            count = unit_gen.index.duplicated(keep='first').sum()
            if count > 3:
                print('The data for generator ' + unit_gen.GenerationUnitEIC.iloc[0] + ' contains more than 3 duplicates in the index')
                #many duplicates with more than 3 duplicates in 2019!

# %% [markdown]
# ## Resampling the data

# %% [markdown]
# Resampling all generation data to hourly generation data per unit and store the data in a new dataframe 'gen_data'. Specific genertor unit data stored in 'unit_data'.

# %%
# set timeframe
t_index = pd.date_range(start=start, end=end, freq='60Min', closed=closed)

# dataframe for generation data
gen_data = pd.DataFrame(index=t_index)

# dataframe for powerplant information
unit_data = pd.DataFrame()


# slicing over all generator units
# takes some time
for i in entsoe_gen_unit.GenerationUnitEIC.unique():
    unit_gen = entsoe_gen_unit.query("GenerationUnitEIC == @i").copy()
    duplicate_count = 0
    unit_gen['duplicate_count'] = duplicate_count
    # test if different resolution codes exist for one power plant
    if len(unit_gen.ResolutionCode.unique()) >= 2:
        print('The data for generator ' + unit_gen.GenerationUnitEIC.iloc[0] + ' contains different time resolutions')
        # for 2018 all data OK
        # for 2019 all data OK
    
    # check if duplicates exist in index (datetime) for the power plant and drop them
    if unit_gen.index.has_duplicates:
        #many duplicates in 2019!
        
        duplicate_count = unit_gen.index.duplicated(keep='first').sum()
        
        #drop all duplicates and only keep the first entry 
        unit_gen = unit_gen[~unit_gen.index.duplicated(keep='first')]
        unit_gen['duplicate_count'] = duplicate_count
    
    #resampling the data to 1h and store it in "gen_data"
    gen_data[i] = resampling(pp_gen=unit_gen, start=start, end=end, resolution='60Min')['ActualGenerationOutput']
   
    #store power plant info in unit_data
    unit_data = unit_data.append((unit_gen.set_index('GenerationUnitEIC')[['AreaCode', 'AreaTypeCode', 'AreaName', 'MapCode', 'PowerSystemResourceName', 'ProductionTypeName','InstalledGenCapacity','duplicate_count']].iloc[0]))

# %% [markdown]
# ## Group the data

# %% [markdown]
# By using the "unit_data" dataframe in combination with the .groupby() function the data can be easily grouped and analyzed.

# %% [markdown]
# ### Hourly data per county and technology

# %%
# will result in a multi index dataframe
data_country_tech_hourly = gen_data.groupby([unit_data.MapCode, unit_data.ProductionTypeName], axis=1).sum()

# %%
data_country_tech_hourly.head()
# Out:
# MapCode                     AT                                        \
# ProductionTypeName  Fossil Gas Fossil Hard coal Hydro Pumped Storage
# 2019-01-01 00:00:00     865.28           154.93                  0.0
# 2019-01-01 01:00:00     575.35           155.50                  0.0
# 2019-01-01 02:00:00     555.05           155.43                  0.0
# 2019-01-01 03:00:00     445.40           154.38                  0.0
# 2019-01-01 04:00:00     430.53           155.28                  0.0
#
# MapCode                                                                    \
# ProductionTypeName  Hydro Run-of-river and poundage Hydro Water Reservoir
# 2019-01-01 00:00:00                         1424.78                 64.68
# 2019-01-01 01:00:00                         1420.00                 22.55
# 2019-01-01 02:00:00                         1417.21                 16.80
# 2019-01-01 03:00:00                         1422.51                 31.60
# 2019-01-01 04:00:00                         1430.05                 10.00
#
# MapCode                                    BA                   \
# ProductionTypeName  Fossil Brown coal/Lignite Fossil Hard coal
# 2019-01-01 00:00:00                       0.0           547.61
# 2019-01-01 01:00:00                       0.0           533.53
# 2019-01-01 02:00:00                       0.0           539.32
# 2019-01-01 03:00:00                       0.0           537.32
# 2019-01-01 04:00:00                       0.0           524.81
#
# MapCode                                                             BE  ...  \
# ProductionTypeName  Hydro Pumped Storage Hydro Water Reservoir Biomass  ...
# 2019-01-01 00:00:00                 0.44                 81.02     0.0  ...
# 2019-01-01 01:00:00                 0.33                 83.96     0.0  ...
# 2019-01-01 02:00:00                 0.44                 78.09     0.0  ...
# 2019-01-01 03:00:00                 0.44                 75.29     0.0  ...
# 2019-01-01 04:00:00                 0.44                 77.60     0.0  ...
#
# MapCode                  SE                        SI             \
# ProductionTypeName  Nuclear Fossil Brown coal/Lignite Fossil Gas
# 2019-01-01 00:00:00  8229.8                    194.82        0.0
# 2019-01-01 01:00:00  8227.6                    184.77        0.0
# 2019-01-01 02:00:00  8226.9                    184.29        0.0
# 2019-01-01 03:00:00  8227.7                    155.79        0.0
# 2019-01-01 04:00:00  8226.2                    145.45        0.0
#
# MapCode                                                                 SK  \
# ProductionTypeName  Hydro Pumped Storage Nuclear Fossil Brown coal/Lignite
# 2019-01-01 00:00:00                  0.0  694.52                     94.14
# 2019-01-01 01:00:00                  0.0  694.55                     77.92
# 2019-01-01 02:00:00                  0.0  694.42                     76.21
# 2019-01-01 03:00:00                  0.0  694.21                     76.64
# 2019-01-01 04:00:00                  0.0  694.35                     75.69
#
# MapCode
# ProductionTypeName  Fossil Gas Fossil Hard coal Hydro Pumped Storage  Nuclear
# 2019-01-01 00:00:00        0.0              0.0                  0.0  1928.22
# 2019-01-01 01:00:00        0.0              0.0                  0.0  1927.29
# 2019-01-01 02:00:00        0.0              0.0                  0.0  1928.61
# 2019-01-01 03:00:00        0.0              0.0                  0.0  1928.89
# 2019-01-01 04:00:00        0.0              0.0                  0.0  1930.43
#
# [5 rows x 146 columns]

# %% [markdown]
# ### Monthly data per county and technology

# %%
# generate month as a grouper
data_country_tech_hourly['Month'] = pd.DatetimeIndex(data_country_tech_hourly.index).month

#will result in a multi index dataframe
data_country_tech_monthly = data_country_tech_hourly.groupby(data_country_tech_hourly.Month, axis=0).sum()

#drop the grouper from resulting dataframe
data_country_tech_monthly.drop(['Month'],axis=1, inplace=True)

# %%
data_country_tech_monthly.head()
# Out:
# MapCode                     AT                                        \
# ProductionTypeName  Fossil Gas Fossil Hard coal Hydro Pumped Storage
# Month
# 1                   1290071.50        177607.57            308108.93
# 2                   1046679.03        185334.52            219515.69
# 3                    593730.84        126163.96            241239.95
# 4                    515224.56         98335.62            238395.94
# 5                    120731.40         75540.27            198002.34
#
# MapCode                                                                   \
# ProductionTypeName Hydro Run-of-river and poundage Hydro Water Reservoir
# Month
# 1                                       1128201.54             156871.64
# 2                                        904000.50             113732.77
# 3                                       1368452.29             114593.18
# 4                                       1169908.42             158598.12
# 5                                       1293754.08             144102.19
#
# MapCode                                   BA                   \
# ProductionTypeName Fossil Brown coal/Lignite Fossil Hard coal
# Month
# 1                                  176556.26        773196.19
# 2                                  178511.91        616443.07
# 3                                  154826.63        674156.20
# 4                                   28068.16        469208.08
# 5                                  202923.06        384148.97
#
# MapCode                                                               BE  ...  \
# ProductionTypeName Hydro Pumped Storage Hydro Water Reservoir    Biomass  ...
# Month                                                                     ...
# 1                              27834.51              82653.15  140586.00  ...
# 2                              53965.58              91314.94   97450.70  ...
# 3                              62715.75              93017.99   36656.90  ...
# 4                              49072.53              94725.81       0.00  ...
# 5                              46496.98             103052.07   32341.85  ...
#
# MapCode                    SE                        SI             \
# ProductionTypeName    Nuclear Fossil Brown coal/Lignite Fossil Gas
# Month
# 1                   6081341.7                 355157.79     823.02
# 2                   5525186.4                 317092.26       0.00
# 3                   5788670.9                 266313.41     170.00
# 4                   5228669.6                 225329.56     130.06
# 5                   4903795.6                 271930.72       0.00
#
# MapCode                                                                   SK  \
# ProductionTypeName Hydro Pumped Storage    Nuclear Fossil Brown coal/Lignite
# Month
# 1                                  0.00  514558.90                 101863.90
# 2                                  0.00  467393.74                  94535.27
# 3                                  0.00  516118.00                 107508.59
# 4                              12169.67  484679.31                 110635.68
# 5                              22335.67  515860.92                 117141.60
#
# MapCode                                                              \
# ProductionTypeName Fossil Gas Fossil Hard coal Hydro Pumped Storage
# Month
# 1                   124084.27         30697.55             22165.44
# 2                    83207.57         41358.53             11129.12
# 3                   105740.38         29405.67             17824.87
# 4                    41551.50         16367.01             12826.54
# 5                   111993.92             0.00             12772.09
#
# MapCode
# ProductionTypeName     Nuclear
# Month
# 1                   1434887.97
# 2                   1284606.15
# 3                   1326762.47
# 4                   1100174.46
# 5                   1292668.69
#
# [5 rows x 146 columns]

# %% [markdown]
# ### Yearly data per county and technology

# %%
# sum the data from multiindex dataframe and convert multiindex into columns and rows
data_country_tech_yearly = data_country_tech_hourly.sum().unstack(-1)

# %%
data_country_tech_yearly.head()
# Out:
# ProductionTypeName     Biomass  Fossil Brown coal/Lignite  \
# MapCode
# AT                         NaN                        NaN
# BA                         NaN                 2057820.17
# BE                  1205194.46                        NaN
# BG                         NaN                16282769.00
# CH                         NaN                        NaN
#
# ProductionTypeName  Fossil Coal-derived gas   Fossil Gas  Fossil Hard coal  \
# MapCode
# AT                                      NaN   8989865.98        1260244.21
# BA                                      NaN          NaN        7384105.72
# BE                                      NaN  18548231.32               NaN
# BG                                      NaN          NaN              0.00
# CH                                      NaN          NaN               NaN
#
# ProductionTypeName  Fossil Oil  Fossil Oil shale  Fossil Peat  Geothermal  \
# MapCode
# AT                         NaN               NaN          NaN         NaN
# BA                         NaN               NaN          NaN         NaN
# BE                         NaN               NaN          NaN         NaN
# BG                         NaN               NaN          NaN         NaN
# CH                         NaN               NaN          NaN         NaN
#
# ProductionTypeName  Hydro Pumped Storage  Hydro Run-of-river and poundage  \
# MapCode
# AT                            2787976.70                      12692772.40
# BA                             896532.78                              NaN
# BE                             878384.73                              NaN
# BG                                   NaN                              NaN
# CH                            4191597.69                       1150563.07
#
# ProductionTypeName  Hydro Water Reservoir      Nuclear  Other  Solar  Waste  \
# MapCode
# AT                             2122815.81          NaN    NaN    NaN    NaN
# BA                              874260.10          NaN    NaN    NaN    NaN
# BE                                    NaN  41423452.19    NaN    NaN    NaN
# BG                                    NaN  14725814.00    NaN    NaN    NaN
# CH                             9993936.52  25721734.80    NaN    NaN    NaN
#
# ProductionTypeName  Wind Offshore  Wind Onshore
# MapCode
# AT                            NaN           NaN NaN
# BA                            NaN           NaN NaN
# BE                      4678460.0           NaN NaN
# BG                            NaN           NaN NaN
# CH                            NaN           NaN NaN

# %% [markdown]
# ### Germany as example

# %%
DE = data_country_tech_hourly['DE']

# %%
DE.head()
# Out:
# ProductionTypeName   Fossil Brown coal/Lignite  Fossil Coal-derived gas  \
# 2019-01-01 00:00:00                    5255.53                   337.25
# 2019-01-01 01:00:00                    5212.24                   359.25
# 2019-01-01 02:00:00                    5148.42                   381.50
# 2019-01-01 03:00:00                    5064.69                   377.75
# 2019-01-01 04:00:00                    4963.17                   340.75
#
# ProductionTypeName   Fossil Gas  Fossil Hard coal  Fossil Oil  \
# 2019-01-01 00:00:00     1692.65           2296.45      173.50
# 2019-01-01 01:00:00     1416.35           2067.99      175.50
# 2019-01-01 02:00:00     1385.41           2188.30      175.50
# 2019-01-01 03:00:00     1391.04           2132.97      176.25
# 2019-01-01 04:00:00     1379.31           2149.48      176.75
#
# ProductionTypeName   Hydro Pumped Storage  Hydro Run-of-river and poundage  \
# 2019-01-01 00:00:00                172.77                           168.35
# 2019-01-01 01:00:00                131.03                           170.46
# 2019-01-01 02:00:00                  9.66                           168.76
# 2019-01-01 03:00:00                 57.24                           156.79
# 2019-01-01 04:00:00                 44.11                           115.70
#
# ProductionTypeName   Hydro Water Reservoir  Nuclear  Waste
# 2019-01-01 00:00:00                    0.0  8526.04   8.48
# 2019-01-01 01:00:00                    0.0  7937.49  10.40
# 2019-01-01 02:00:00                    0.0  7212.16   9.38
# 2019-01-01 03:00:00                    0.0  7115.15  11.63
# 2019-01-01 04:00:00                    0.0  7051.23  11.53

# %%
# production per technology in GWh
DE.sum()/1000
# Out:
# ProductionTypeName
# Fossil Brown coal/Lignite          101758.58636
# Fossil Coal-derived gas              2128.61400
# Fossil Gas                          38036.83131
# Fossil Hard coal                    47802.35821
# Fossil Oil                           1382.43683
# Hydro Pumped Storage                 6775.89544
# Hydro Run-of-river and poundage      1699.71752
# Hydro Water Reservoir                 679.09450
# Nuclear                             70915.30455
# Waste                                 256.23373
# dtype: float64

# %%
ax = sns.barplot(data=DE)

# %% [markdown]
# ## Export data

# %% [markdown]
# Save data as .csv files. All files are saved in the output directory of this notebook. Take some time (2 min)

# %%
# hourly data
data_country_tech_hourly.to_csv(output_directory_path + '/data_country_tech_hourly.csv')

# monthly data
data_country_tech_monthly.to_csv(output_directory_path + '/data_country_tech_monthly.csv')

# yearly data
data_country_tech_yearly.to_csv(output_directory_path + '/data_country_tech_yearly.csv')

# power plant information
unit_data.to_csv(output_directory_path + '/unit_data.csv')

# hourly unit generation data
gen_data.to_csv(output_directory_path + '/gen_data.csv')
